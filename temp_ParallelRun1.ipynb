# %%
import pandas as pd
import numpy as np
import math
import math
from Util import *
from CLT_class import CLT
from __future__ import print_function

datasetList = ["pumsb_star","tretail"]
data = {}
for i in datasetList:
    data[i+".ts.data"] = Util.load_dataset("datasets\\dataset\\"+i+".ts.data")
    data[i+".test.data"] = Util.load_dataset("datasets\\dataset\\"+i+".test.data")
    data[i+".valid.data"] = Util.load_dataset("datasets\\dataset\\"+i+".valid.data")

# %%
class MIXTURE_CLT():
   
    def __init__(self):
        self.n_components = 0 # number of components
        self.mixture_probs = None # mixture probabilities
        self.clt_list =[]   # List of Tree Bayesian networks

    '''
        Learn Mixtures of Trees using the EM algorithm.
    '''
    def learn(self, dataset, n_components=2, max_iter=50, epsilon=format(1e-1, '.6f')):
        # For each component and each data point, we have a weight
        weights=np.random.random((n_components , dataset.shape[0]))
        self.mixture_probs = np.zeros(n_components)
 
        # Randomly initialize the chow-liu trees and the mixture probabilities
        # Your code for random initialization goes here
 
        for i in range(n_components):
            self.clt_list.append(CLT())
            self.clt_list[i].learn(dataset)
 
        a = np.random.rand(n_components)
        for i in range(len(a)):
            self.mixture_probs[i] = a[i] / np.sum(a)  

        like = 0.0
        old_like = 999
        prob = np.zeros((n_components , dataset.shape[0]))


        for itr in range(max_iter):
           
            print("Iteration - ",itr)
            print("N components - ",n_components)
           
            #E-step: Complete the dataset to yield a weighted dataset
            # We store the weights in an array weights[ncomponents,number of points]
            #Your code for E-step here
            
            if abs(old_like - like) <= epsilon:
                break


            for i in range(n_components):
                for j in range(dataset.shape[0]):
                    prob[i][j] = self.clt_list[i].getProb(dataset[j])
                weights[i] = np.multiply(self.mixture_probs[i], prob[i])/np.sum(np.multiply(self.mixture_probs[i], prob[i]))
                # print(weights.shape)
        
            # # M-step: Update the Chow-Liu Trees and the mixture probabilities
            # #Your code for M-Step here
            for i in range(n_components):
                self.clt_list[i].update(dataset, weights[i])
                self.mixture_probs[i] = weights[i].sum()/len(weights[i])
                
            old_like = like
            like = self.computeLL(dataset , n_components) / dataset.shape[0]
            print(like)

         
           
    # """
    #     Compute the log-likelihood score of the dataset
    # """
    def computeLL(self, dataset , n_components):
        ll = 0.0
        likelihood=0.0

        # Write your code below to compute likelihood of data
        #   Hint:   Likelihood of a data point "x" is sum_{c} P(c) T(x|c)
        #           where P(c) is mixture_prob of cth component and T(x|c) is the probability w.r.t. chow-liu tree at c
        #           To compute T(x|c) you can use the function given in class CLT
        for i in range (dataset.shape[0]):
            for j in range(n_components):
                likelihood=likelihood + self.mixture_probs[j]*self.clt_list[j].getProb(dataset[i])
            ll=ll+ np.log(likelihood)


        return ll

# %%
#MCLT
kval = {}
items = list(data.keys())
# mix_clt=MIXTURE_CLT.MIXTURE_CLT()
ncomponents=10 #number of components
max_iter=50 #max number of iterations for EM
epsilon=1e-2 #converge if the difference in the log-likelihods between two iterations is smaller 1e-1


i = 0

kvals = [2,5,10,20]
while i < 30:
    kMixCLT = [MIXTURE_CLT() for p in kvals]
    p = 0
    temp = []
    print("Running for dataset - ", items[i])
    for k in kvals:
        t = i 
        # print([items[t]])
        kMixCLT[p].learn(data[items[t]],k,max_iter,epsilon)
        t += 2
        x = kMixCLT[p].computeLL(data[items[t]] , k)/data[items[t]].shape[0]
        print("LL for ", k , " - ", x  )
        temp.append(x)
        p += 1
        
    kval[items[i]] = [ kvals[temp.index(max(temp))] , max(temp)] 

    print(temp)
    print(kval)
    i += 3
# Out:
# Running for dataset -  pumsb_star.ts.data
# Iteration -  0
# N components -  2
# -11.00691165214752
# Iteration -  1
# N components -  2
# -9.71731322284354
# Iteration -  2
# N components -  2
# -8.847819606520764
# Iteration -  3
# N components -  2
# -8.462277172892813
# Iteration -  4
# N components -  2
# -8.369760780816172
# Iteration -  5
# N components -  2
# -8.389251918408108
# Iteration -  6
# N components -  2
# -8.455302359937438
# Iteration -  7
# N components -  2
# -8.499509717785337
# Iteration -  8
# N components -  2
# -8.593797923432064
# Iteration -  9
# N components -  2
# -8.660800697212153
# Iteration -  10
# N components -  2
# -8.720943325792216
# Iteration -  11
# N components -  2
# -8.773684677239205
# Iteration -  12
# N components -  2
# -8.818760135698195
# Iteration -  13
# N components -  2
# -8.856459152144653
# Iteration -  14
# N components -  2
# -8.887963263299024
# Iteration -  15
# N components -  2
# -8.914688242482422
# Iteration -  16
# N components -  2
# -8.937881361447328
# Iteration -  17
# N components -  2
# -8.958441184963199
# Iteration -  18
# N components -  2
# -8.976892296088899
# Iteration -  19
# N components -  2
# -8.993438161978416
# Iteration -  20
# N components -  2
# -9.008056745549524
# Iteration -  21
# N components -  2
# -9.020633879890633
# Iteration -  22
# N components -  2
# -9.031115530796718
# Iteration -  23
# N components -  2
# -9.039618051123144
# Iteration -  24
# N components -  2
# LL for  2  -  -19.5962588651615
# Iteration -  0
# N components -  5
# -10.090620920273592
# Iteration -  1
# N components -  5
# -8.801022490968997
# Iteration -  2
# N components -  5
# -7.931528874646699
# Iteration -  3
# N components -  5
# -7.545986441018565
# Iteration -  4
# N components -  5
# -7.45347004894219
# Iteration -  5
# N components -  5
# -7.472961186533929
# Iteration -  6
# N components -  5
# -7.539011628060015
# Iteration -  7
# N components -  5
# -7.583218985911085
# Iteration -  8
# N components -  5
# -7.677507191467153
# Iteration -  9
# N components -  5
# -7.745062348750938
# Iteration -  10
# N components -  5
# -7.805209361161673
# Iteration -  11
# N components -  5
# -7.857951783055227
# Iteration -  12
# N components -  5
# -7.90302770697989
# Iteration -  13
# N components -  5
# -7.940726958745866
# Iteration -  14
# N components -  5
# -7.972231200702697
# Iteration -  15
# N components -  5
# -7.998956254633891
# Iteration -  16
# N components -  5
# -8.021590626811557
# Iteration -  17
# N components -  5
# -8.042150449339676
# Iteration -  18
# N components -  5
# -8.06060156108578
# Iteration -  19
# N components -  5
# -8.077147427547263
# Iteration -  20
# N components -  5
# -8.091766011617622
# Iteration -  21
# N components -  5
# -8.104343146375745
# Iteration -  22
# N components -  5
# -8.114824797618919
# Iteration -  23
# N components -  5
# -8.12332731820952
# Iteration -  24
# N components -  5
# LL for  5  -  -18.69203336870446
# Iteration -  0
# N components -  10
# -9.397473739713673
# Iteration -  1
# N components -  10
# -8.107875310409241
# Iteration -  2
# N components -  10
# -7.238381694086833
# Iteration -  3
# N components -  10
# -6.852839260458345
# Iteration -  4
# N components -  10
# -6.760322868382064
# Iteration -  5
# N components -  10
# -6.779814005973795
# Iteration -  6
# N components -  10
# -6.845864447498564
# Iteration -  7
# N components -  10
# -6.890071805351282
# Iteration -  8
# N components -  10
# -6.984360010906104
# Iteration -  9
# N components -  10
# -7.051915168190643
# Iteration -  10
# N components -  10
# -7.112062180601535
# Iteration -  11
# N components -  10
# -7.164804602495877
# Iteration -  12
# N components -  10
# -7.209880526419916
# Iteration -  13
# N components -  10
# -7.2475797781861475
# Iteration -  14
# N components -  10
# -7.279084020142985
# Iteration -  15
# N components -  10
# -7.3058090740742365
# Iteration -  16
# N components -  10
# -7.328443446251557
# Iteration -  17
# N components -  10
# -7.34900326878012
# Iteration -  18
# N components -  10
# -7.367454380525292
# Iteration -  19
# N components -  10
# -7.384000246987262
# Iteration -  20
# N components -  10
# -7.398618831057387
# Iteration -  21
# N components -  10
# -7.411195965815744
# Iteration -  22
# N components -  10
# -7.421677617059324
# Iteration -  23
# N components -  10
# -7.430180137650037
# Iteration -  24
# N components -  10
# LL for  10  -  -17.9898996615938
# Iteration -  0
# N components -  20
# -8.704326559153861
# Iteration -  1
# N components -  20
# -7.414728129849355
# Iteration -  2
# N components -  20
# -6.5452345135269905
# Iteration -  3
# N components -  20
# -6.159692079898852
# Iteration -  4
# N components -  20
# -6.0671756878221155
# Iteration -  5
# N components -  20
# -6.0866668254140714
# Iteration -  6
# N components -  20
# -6.152717266940039
# Iteration -  7
# N components -  20
# -6.196924624790167
# Iteration -  8
# N components -  20
# -6.2912128303428005
# Iteration -  9
# N components -  20
# -6.358813675957006
# Iteration -  10
# N components -  20
# -6.418961071132877
# Iteration -  11
# N components -  20
# -6.471703562462406
# Iteration -  12
# N components -  20
# -6.516779516026555
# Iteration -  13
# N components -  20
# -6.554478782789227
# Iteration -  14
# N components -  20
# -6.585983033089275
# Iteration -  15
# N components -  20
# -6.6127080917891865
# Iteration -  16
# N components -  20
# -6.635296265548133
# Iteration -  17
# N components -  20
# -6.655856088010395
# Iteration -  18
# N components -  20
# -6.674307199790649
# Iteration -  19
# N components -  20
# -6.690853066284045
# Iteration -  20
# N components -  20
# -6.705471650382144
# Iteration -  21
# N components -  20
# -6.718048785163713
# Iteration -  22
# N components -  20
# -6.7285304364249585
# Iteration -  23
# N components -  20
# -6.737032957030231
# Iteration -  24
# N components -  20
# LL for  20  -  -17.298446571656125
# [-19.5962588651615, -18.69203336870446, -17.9898996615938, -17.298446571656125]
# {'pumsb_star.ts.data': [20, -17.298446571656125]}
# Running for dataset -  tretail.ts.data
# Iteration -  0
# N components -  2
# -3.1083275642636776
# Iteration -  1
# N components -  2
# -2.970671295874542
# Iteration -  2
# N components -  2
# -2.9043202389490173
# Iteration -  3
# N components -  2
# -2.862448524231059
# Iteration -  4
# N components -  2
# -2.835483916934095
# Iteration -  5
# N components -  2
# -2.8183062996953723
# Iteration -  6
# N components -  2
# -2.80751125246443
# Iteration -  7
# N components -  2
# -2.8007943625234573
# Iteration -  8
# N components -  2
# LL for  2  -  -5.0269951236310595
# Iteration -  0
# N components -  5
# -2.192036832389522
# Iteration -  1
# N components -  5
# -2.054380564000328
# Iteration -  2
# N components -  5
# -1.9880295070748313
# Iteration -  3
# N components -  5
# -1.9461577923570295
# Iteration -  4
# N components -  5
# -1.919193185059991
# Iteration -  5
# N components -  5
# -1.9020155678212276
# Iteration -  6
# N components -  5
# -1.8912205205902453
# Iteration -  7
# N components -  5
# -1.884503630649249
# Iteration -  8
# N components -  5
# LL for  5  -  -4.110704391756947
# Iteration -  0
# N components -  10
# -1.498889651829579
# Iteration -  1
# N components -  10
# -1.3612333834402448
# Iteration -  2
# N components -  10
# -1.2948823265150469
# Iteration -  3
# N components -  10
# -1.2530106117970798
# Iteration -  4
# N components -  10
# -1.2260460045000543
# Iteration -  5
# N components -  10
# -1.2088683872611874
# Iteration -  6
# N components -  10
# -1.1980733400303467
# Iteration -  7
# N components -  10
# -1.1913564500892058
# Iteration -  8
# N components -  10
# LL for  10  -  -3.417557211197011
# Iteration -  0
# N components -  20
# -0.8057424712701919
# Iteration -  1
# N components -  20
# -0.6680862028803015
# Iteration -  2
# N components -  20
# -0.6017351459552316
# Iteration -  3
# N components -  20
# -0.5598634312367862
# Iteration -  4
# N components -  20
# -0.532898823939781
# Iteration -  5
# N components -  20
# -0.515721206701219
# Iteration -  6
# N components -  20
# -0.5049261594705614
# Iteration -  7
# N components -  20
# -0.49820926952943356
# Iteration -  8
# N components -  20
# LL for  20  -  -2.72441003063707
# [-5.0269951236310595, -4.110704391756947, -3.417557211197011, -2.72441003063707]
# {'pumsb_star.ts.data': [20, -17.298446571656125], 'tretail.ts.data': [20, -2.72441003063707]}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1472/1349604260.py in <module>
#      15     p = 0
#      16     temp = []
# ---> 17     print("Running for dataset - ", items[i])
#      18     for k in kvals:
#      19         t = i
#
# IndexError: list index out of range

# %%
kval = {}
kval["pumsb_star.ts.data"] = [20, -17.298446571656125]
kval["tretail.ts.data"] = [20, -2.72441003063707]

# %%
# kval =["pumsb_star","tretail"]
items = list(data.keys())
ncomponents=20
max_iter=50 
epsilon=1e-1 
i = 0
temp = []

for k in kval.keys():
    for i in range(5):
        clt = MIXTURE_CLT()
        print("Testing for dataset - " , k)
        clt.learn(data[k+".ts.data"],20,max_iter,epsilon)
        x = clt.computeLL( data[k+".test.data"] , 20)/data[k+".test.data"].shape[0]
        print("LL for testing - " , x  )
        temp.append(x)
            

        print(temp)
        print(kval)
# Out:
# Testing for dataset -  pumsb_star
# Iteration -  0
# N components -  20
# -8.704326559153861
# Iteration -  1
# N components -  20
# -7.414728129849355
# Iteration -  2
# N components -  20
# -6.5452345135269905
# Iteration -  3
# N components -  20
# -6.159692079898852
# Iteration -  4
# N components -  20
# -6.0671756878221155
# Iteration -  5
# N components -  20
# LL for testing -  -12.668696522691103
# [-12.668696522691103]
# {'pumsb_star': [20, -17.298446571656125], 'tretail': [20, -2.72441003063707]}
# Testing for dataset -  pumsb_star
# Iteration -  0
# N components -  20
# -8.704326559153861
# Iteration -  1
# N components -  20
# -7.4147281298493555
# Iteration -  2
# N components -  20
# -6.5452345135269905
# Iteration -  3
# N components -  20
# -6.159692079898852
# Iteration -  4
# N components -  20
# -6.0671756878221155
# Iteration -  5
# N components -  20
# LL for testing -  -12.664418899268348
# [-12.668696522691103, -12.664418899268348]
# {'pumsb_star': [20, -17.298446571656125], 'tretail': [20, -2.72441003063707]}
# Testing for dataset -  pumsb_star
# Iteration -  0
# N components -  20
# -8.704326559153861
# Iteration -  1
# N components -  20
# -7.414728129849356
# Iteration -  2
# N components -  20
# -6.5452345135269905
# Iteration -  3
# N components -  20
# -6.159692079898852
# Iteration -  4
# N components -  20
# -6.0671756878221155
# Iteration -  5
# N components -  20
# LL for testing -  -12.668842776385073
# [-12.668696522691103, -12.664418899268348, -12.668842776385073]
# {'pumsb_star': [20, -17.298446571656125], 'tretail': [20, -2.72441003063707]}
# Testing for dataset -  pumsb_star
# Iteration -  0
# N components -  20
# -8.704326559153861
# Iteration -  1
# N components -  20
# -7.4147281298493555
# Iteration -  2
# N components -  20
# -6.5452345135269905
# Iteration -  3
# N components -  20
# -6.159692079898852
# Iteration -  4
# N components -  20
# -6.0671756878221155
# Iteration -  5
# N components -  20
# LL for testing -  -12.664634154432097
# [-12.668696522691103, -12.664418899268348, -12.668842776385073, -12.664634154432097]
# {'pumsb_star': [20, -17.298446571656125], 'tretail': [20, -2.72441003063707]}
# Testing for dataset -  pumsb_star
# Iteration -  0
# N components -  20
# -8.704326559153861
# Iteration -  1
# N components -  20
# -7.414728129849355
# Iteration -  2
# N components -  20
# -6.5452345135269905
# Iteration -  3
# N components -  20
# -6.159692079898852
# Iteration -  4
# N components -  20
# -6.0671756878221155
# Iteration -  5
# N components -  20
# LL for testing -  -12.663879403661289
# [-12.668696522691103, -12.664418899268348, -12.668842776385073, -12.664634154432097, -12.663879403661289]
# {'pumsb_star': [20, -17.298446571656125], 'tretail': [20, -2.72441003063707]}
# Testing for dataset -  tretail
# Iteration -  0
# N components -  20
# -0.8057424712701919
# Iteration -  1
# N components -  20
# -0.6680862028803015
# Iteration -  2
# N components -  20
# -0.601735145955231
# Iteration -  3
# N components -  20
# LL for testing -  -2.2936164536503885
# [-12.668696522691103, -12.664418899268348, -12.668842776385073, -12.664634154432097, -12.663879403661289, -2.2936164536503885]
# {'pumsb_star': [20, -17.298446571656125], 'tretail': [20, -2.72441003063707]}
# Testing for dataset -  tretail
# Iteration -  0
# N components -  20
# -0.8057424712701919
# Iteration -  1
# N components -  20
# -0.6680862028803015
# Iteration -  2
# N components -  20
# -0.6017351459552315
# Iteration -  3
# N components -  20
# LL for testing -  -2.2936164536503894
# [-12.668696522691103, -12.664418899268348, -12.668842776385073, -12.664634154432097, -12.663879403661289, -2.2936164536503885, -2.2936164536503894]
# {'pumsb_star': [20, -17.298446571656125], 'tretail': [20, -2.72441003063707]}
# Testing for dataset -  tretail
# Iteration -  0
# N components -  20
# -0.8057424712701919
# Iteration -  1
# N components -  20
